# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import (
    train_test_split,
    learning_curve,
    StratifiedKFold
)

from sklearn.preprocessing import (
    LabelEncoder,
    StandardScaler
)

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier
)

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    confusion_matrix,
    classification_report
)

import xgboost as xgb

import warnings
warnings.filterwarnings("ignore")

plt.style.use("seaborn-v0_8-darkgrid")
sns.set_palette("husl")

print("CUSTOMER CHURN PREDICTION MODEL COMPARISON")
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[2], line 36
#      32     confusion_matrix,
#      33     classification_report
#      34 )
#      35
# ---> 36 import xgboost as xgb
#      37
#      38 import warnings
#      39 warnings.filterwarnings("ignore")
#
# File ~/Documents/Qiyas_AI/venv/lib/python3.11/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)     15     build_info,
#      16 )
#
# File ~/Documents/Qiyas_AI/venv/lib/python3.11/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, _deprecate_positional_args, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/Documents/Qiyas_AI/venv/lib/python3.11/site-packages/xgboost/core.py:309
#     305     return lib
#     308 # load the XGBoost library globally
# --> 309 _LIB = _load_lib()
#     312 def _check_call(ret: int) -> None:
#     313     """Check the return value of C API call
#     314
#     315     This function will raise exception when error occurs.
#    (...)    321         return value from API calls
#     322     """
#
# File ~/Documents/Qiyas_AI/venv/lib/python3.11/site-packages/xgboost/core.py:273, in _load_lib()
#     271     if not lib_success:
#     272         libname = os.path.basename(lib_paths[0])
# --> 273         raise XGBoostError(f"""
#     274 XGBoost Library ({libname}) could not be loaded.
#     275 Likely causes:
#     276   * OpenMP runtime is not installed
#     277     - vcomp140.dll or libgomp-1.dll for Windows
#     278     - libomp.dylib for Mac OSX
#     279     - libgomp.so for Linux and other UNIX-like OSes
#     280     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     281
#     282   * You are running 32-bit Python on a 64-bit OS
#     283
#     284 Error message(s): {os_error_list}
#     285 """)
#     286     _register_log_callback(lib)
#     288     libver = _lib_version(lib)
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ['dlopen(/Users/mac1/Documents/Qiyas_AI/venv/lib/python3.11/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: @rpath/libomp.dylib\n  Referenced from: /Users/mac1/Documents/Qiyas_AI/venv/lib/python3.11/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']
